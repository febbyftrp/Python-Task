# %% [markdown]
# <a href="https://colab.research.google.com/github/febbyftrp/Python-Task/blob/main/Assignment13_CreateGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 13 Create Graph 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800 #MHz
loc1   ='urban'
loc2   ='suburban'
loc3   ='open'
tower = 80 #m
user  = 1.5 #m
dmin  = 200 #m
dmax  = 700 #m
N     = 200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
print(d)
# Out:
# [280 498 498 354 386 474 484 237 244 458 275 218 204 649 378 698 417 443
#  256 668 395 201 365 590 508 530 616 229 506 645 602 274 342 570 643 484
#  480 537 517 567 681 446 582 303 218 421 655 631 389 516 309 224 646 446
#  461 232 570 536 525 675 209 314 643 669 348 607 275 392 506 453 558 566
#  563 684 539 407 277 324 496 571 416 317 589 227 503 248 676 428 570 398
#  226 385 300 286 691 664 366 253 425 255 536 294 295 286 515 435 318 468
#  330 201 483 228 463 397 627 405 473 594 231 567 593 685 353 478 581 210
#  311 611 553 520 561 558 619 483 478 301 589 233 694 448 574 524 602 232
#  397 534 453 491 634 635 481 635 323 271 458 497 530 636 446 430 639 310
#  206 505 269 601 590 444 290 426 418 633 654 265 255 404 599 247 480 319
#  292 591 607 669 373 526 582 525 684 646 623 339 321 617 334 397 405 365
#  657 213]

# %%
LpUrban=cos(f,loc1,tower,user,d)
LpSuburban=cos(f,loc2,tower,user,d)
LpOpen=cos(f,loc3,tower,user,d)

# %%
print(LpUrban)
# Out:
# [174.3803199  182.49132302 182.49132302 177.68364557 178.902675
#  181.79556493 182.08965155 172.03172909 172.44175248 181.31186977
#  174.12650695 170.85461155 169.91963656 186.22181849 178.60766448
#  187.24710481 179.99082068 180.84280631 173.11802175 186.62828331
#  179.22734017 169.71094774 178.11469065 184.87925665 182.77137672
#  183.36857064 185.48671757 171.54803393 182.71580964 186.13473173
#  185.16288176 174.07519091 177.19786511 184.39347619 186.09098562
#  182.08965155 181.97275265 183.5533974  183.01875116 184.31914231
#  186.89978332 180.93787689 184.68695008 175.4923326  170.85461155
#  180.12529653 186.35144736 185.82561694 179.01173029 182.99147866
#  175.76854219 171.23706683 186.15655395 180.93787689 181.40383683
#  171.7313715  184.39347619 183.52714159 183.2350508  186.77512553
#  170.26072435 175.99465037 186.09098562 186.64935472 177.44284933
#  185.2793939  174.12650695 179.11994775 182.71580964 181.15724431
# ...

# %%
print(LpSuburban)
# Out:
# [170.8127778  178.92378091 178.92378091 174.11610347 175.33513289
#  178.22802283 178.52210945 168.46418699 168.87421038 177.74432766
#  170.55896485 167.28706944 166.35209446 182.65427638 175.04012237
#  183.67956271 176.42327858 177.27526421 169.55047964 183.0607412
#  175.65979807 166.14340564 174.54714854 181.31171455 179.20383462
#  179.80102853 181.91917547 167.98049183 179.14826754 182.56718963
#  181.59533965 170.50764881 173.630323   180.82593408 182.52344351
#  178.52210945 178.40521054 179.9858553  179.45120905 180.7516002
#  183.33224121 177.37033479 181.11940798 171.9247905  167.28706944
#  176.55775442 182.78390525 182.25807483 175.44418818 179.42393656
#  172.20100008 167.66952473 182.58901184 177.37033479 177.83629472
#  168.16382939 180.82593408 179.95959949 179.66750869 183.20758343
#  166.69318225 172.42710827 182.52344351 183.08181262 173.87530722
#  181.71185179 170.55896485 175.55240565 179.14826754 177.58970221
# ...

# %%
print(LpOpen)
# Out:
# [171.21137746 179.32238057 179.32238057 174.51470313 175.73373256
#  178.62662249 178.92070911 168.86278665 169.27281004 178.14292732
#  170.95756451 167.6856691  166.75069412 183.05287604 175.43872203
#  184.07816237 176.82187824 177.67386387 169.9490793  183.45934086
#  176.05839773 166.5420053  174.9457482  181.71031421 179.60243428
#  180.19962819 182.31777513 168.37909149 179.5468672  182.96578929
#  181.99393931 170.90624847 174.02892266 181.22453374 182.92204318
#  178.92070911 178.8038102  180.38445496 179.84980871 181.15019986
#  183.73084087 177.76893445 181.51800764 172.32339016 167.6856691
#  176.95635408 183.18250491 182.65667449 175.84278784 179.82253622
#  172.59959974 168.06812439 182.98761151 177.76893445 178.23489438
#  168.56242905 181.22453374 180.35819915 180.06610836 183.60618309
#  167.09178191 172.82570793 182.92204318 183.48041228 174.27390688
#  182.11045145 170.95756451 175.95100531 179.5468672  177.98830187
# ...

# %%
plt.figure()
plt.plot(d,LpUrban,'r', label='Urban')
plt.plot(d,LpSuburban,'g', label='Suburban')
plt.plot(d,LpOpen,'b', label='Open')
plt.legend()
plt.title('1800 MHz Frequency with  3 Locations')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]

# %%
d_sort=d[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]

# %%
d_sort=d[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r', label='Urban')
plt.plot(d_sort,Suburban_sort,'g', label='Suburban')
plt.plot(d_sort,Open_sort,'b', label='Open')
plt.legend()
plt.title('1800 MHz Frequency with  3 Locations')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %% [markdown]
# # Assignment 13 Create Graph 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f1    =700 #MHz
f2    =900 #MHz
f3    =1800 #MHz
loc   ='urban'
tower = 80 #m
user  = 1.5 #m
dmin  = 200 #m
dmax  = 700 #m
N     = 200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
print(d)
# Out:
# [328 554 644 371 679 313 355 412 533 207 658 629 233 369 462 290 245 692
#  253 497 289 309 425 565 279 202 330 569 424 610 423 485 210 605 534 535
#  670 344 576 217 208 315 572 608 665 385 235 541 257 364 343 296 413 643
#  690 253 460 379 268 284 504 439 305 572 687 494 220 450 489 255 474 245
#  395 682 482 520 599 518 226 457 616 216 354 412 357 565 403 218 605 617
#  515 217 487 308 464 373 212 452 385 681 208 553 536 305 693 604 306 237
#  494 378 457 204 388 426 525 617 294 463 698 359 487 622 333 210 349 359
#  476 668 561 372 509 485 241 215 550 623 202 394 306 301 379 606 641 269
#  514 324 615 625 599 425 542 621 276 398 242 458 223 514 228 369 399 443
#  644 208 635 619 684 619 624 473 260 560 487 593 529 475 618 452 230 348
#  455 294 413 504 345 498 500 339 362 302 358 491 392 409 390 373 408 211
#  451 266]

# %%
LpUrban1=cos(f1,loc,tower,user,d)
LpUrban2=cos(f2,loc,tower,user,d)
LpUrban3=cos(f3,loc,tower,user,d)

# %%
print(LpUrban1)
print(LpUrban2)
print(LpUrban3)
# Out:
# [163.97004333 171.35335993 173.47381816 165.70530516 174.21929568
#  163.31066066 165.08432361 167.1818427  170.80902175 157.48622122
#  173.77675968 173.14184119 159.15290006 165.62916315 168.79530207
#  162.23556707 159.86030749 174.48643876 160.31291631 169.82395147
#  162.1869099  163.12948469 167.61944322 171.63031007 161.69086436
#  157.14179728 164.05567422 171.72968429 167.58626007 172.7097839
#  167.55299858 169.47966783 157.6889044  172.59384713 170.8354252
#  170.86177926 174.03133717 164.64094334 171.90191991 158.15078963
#  157.55410684 163.40038223 171.80375758 172.66352363 173.92582179
#  166.22707731 159.27329599 171.01887647 160.53388143 165.43698776
#  164.59993534 162.52403253 167.21599117 173.45192813 174.44566814
#  160.31291631 168.73419031 166.00582296 161.12424826 161.94107054
#  170.02096499 168.07598161 162.94594806 171.80375758 174.3842901
#  169.73866622 158.34419639 168.42459021 169.59536653 160.42383214
# ...

# %%
plt.figure()
plt.plot(d,LpUrban1,'b',label='700 Mhz')
plt.plot(d,LpUrban2,'r',label='900 Mhz')
plt.plot(d,LpUrban3,'g',label='1800 Mhz')
plt.legend()
plt.title('Urban Location with 3 Frequencies')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
d_sort=d[np.argsort(d)]
Urban1_sort=LpUrban1[np.argsort(d)]

# %%
d_sort=d[np.argsort(d)]
Urban2_sort=LpUrban2[np.argsort(d)]

# %%
d_sort=d[np.argsort(d)]
Urban3_sort=LpUrban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban1_sort,'b',label='700 Mhz')
plt.plot(d_sort,Urban2_sort,'r',label='900 Mhz')
plt.plot(d_sort,Urban3_sort,'g',label='1800 Mhz')
plt.legend()
plt.title('Urban Location with 3 Frequencies')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
